# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %%
#Add your file path here
stock_path = os.path.join("Resources","FB_daily_stock_yahoo.csv")
employee_reviews_path = os.path.join("Resources","employee_reviews.csv")

# %% [markdown]
# ## Facebook Stock Data

# %%
stock = pd.read_csv(stock_path)
stock_price=stock[['Date','Close']]
stock_price.head()
# Out:
#          Date       Close
# 0  2017-01-03  116.860001
# 1  2017-01-04  118.690002
# 2  2017-01-05  120.669998
# 3  2017-01-06  123.410004
# 4  2017-01-09  124.900002

# %%
#Get the average stock price per month
stock["YYYY-MM"] = [x[:7] for x in stock["Date"]]
stock_grouped = stock.groupby("YYYY-MM")
stock_monthly = pd.DataFrame(stock_grouped["Close"].mean())
stock_monthly["Year Month"] = pd.to_datetime(stock_monthly.index)
stock_monthly.head()
# Out:
#               Close Year Month
# YYYY-MM
# 2017-01  126.817499 2017-01-01
# 2017-02  133.830525 2017-02-01
# 2017-03  139.408261 2017-03-01
# 2017-04  142.965263 2017-04-01
# 2017-05  150.234093 2017-05-01

# %%
employment="employmentrates.csv"
employment_rate = pd.read_csv(employment)

# %%
employment_rate["Time"] = pd.to_datetime(employment_rate["Time"])
employment=employment_rate.rename(columns={"Time":"Year Month","Value":"Employment Rate" })
employment.head(20)
# Out:
#    LOCATION        Country   SUBJECT                               Subject  \
# 0       USA  United States  LREM64FE  Employment rate, Aged 15-64, Females
# 1       USA  United States  LREM64FE  Employment rate, Aged 15-64, Females
# 2       USA  United States  LREM64FE  Employment rate, Aged 15-64, Females
# 3       USA  United States  LREM64FE  Employment rate, Aged 15-64, Females
# 4       USA  United States  LREM64FE  Employment rate, Aged 15-64, Females
# 5       USA  United States  LREM64FE  Employment rate, Aged 15-64, Females
# 6       USA  United States  LREM64FE  Employment rate, Aged 15-64, Females
# 7       USA  United States  LREM64FE  Employment rate, Aged 15-64, Females
# 8       USA  United States  LREM64FE  Employment rate, Aged 15-64, Females
# 9       USA  United States  LREM64FE  Employment rate, Aged 15-64, Females
# 10      USA  United States  LREM64FE  Employment rate, Aged 15-64, Females
# 11      USA  United States  LREM64FE  Employment rate, Aged 15-64, Females
# 12      USA  United States  LREM64FE  Employment rate, Aged 15-64, Females
# 13      USA  United States  LREM64FE  Employment rate, Aged 15-64, Females
# 14      USA  United States  LREM64FE  Employment rate, Aged 15-64, Females
# 15      USA  United States  LREM64FE  Employment rate, Aged 15-64, Females
# 16      USA  United States  LREM64FE  Employment rate, Aged 15-64, Females
# 17      USA  United States  LREM64FE  Employment rate, Aged 15-64, Females
# 18      USA  United States  LREM64FE  Employment rate, Aged 15-64, Females
# 19      USA  United States  LREM64FE  Employment rate, Aged 15-64, Females
#
#    MEASURE                               Measure FREQUENCY Frequency     TIME  \
# 0     STSA  Level, rate or quantity series, s.a.         M   Monthly  2016-01
# 1     STSA  Level, rate or quantity series, s.a.         M   Monthly  2016-02
# 2     STSA  Level, rate or quantity series, s.a.         M   Monthly  2016-03
# 3     STSA  Level, rate or quantity series, s.a.         M   Monthly  2016-04
# 4     STSA  Level, rate or quantity series, s.a.         M   Monthly  2016-05
# 5     STSA  Level, rate or quantity series, s.a.         M   Monthly  2016-06
# 6     STSA  Level, rate or quantity series, s.a.         M   Monthly  2016-07
# 7     STSA  Level, rate or quantity series, s.a.         M   Monthly  2016-08
# 8     STSA  Level, rate or quantity series, s.a.         M   Monthly  2016-09
# 9     STSA  Level, rate or quantity series, s.a.         M   Monthly  2016-10
# 10    STSA  Level, rate or quantity series, s.a.         M   Monthly  2016-11
# 11    STSA  Level, rate or quantity series, s.a.         M   Monthly  2016-12
# 12    STSA  Level, rate or quantity series, s.a.         M   Monthly  2017-01
# 13    STSA  Level, rate or quantity series, s.a.         M   Monthly  2017-02
# 14    STSA  Level, rate or quantity series, s.a.         M   Monthly  2017-03
# 15    STSA  Level, rate or quantity series, s.a.         M   Monthly  2017-04
# 16    STSA  Level, rate or quantity series, s.a.         M   Monthly  2017-05
# 17    STSA  Level, rate or quantity series, s.a.         M   Monthly  2017-06
# 18    STSA  Level, rate or quantity series, s.a.         M   Monthly  2017-07
# 19    STSA  Level, rate or quantity series, s.a.         M   Monthly  2017-08
#
#    Year Month Unit Code        Unit  PowerCode Code PowerCode  \
# 0  2016-01-01        PC  Percentage               0     Units
# 1  2016-02-01        PC  Percentage               0     Units
# 2  2016-03-01        PC  Percentage               0     Units
# 3  2016-04-01        PC  Percentage               0     Units
# 4  2016-05-01        PC  Percentage               0     Units
# 5  2016-06-01        PC  Percentage               0     Units
# 6  2016-07-01        PC  Percentage               0     Units
# 7  2016-08-01        PC  Percentage               0     Units
# 8  2016-09-01        PC  Percentage               0     Units
# 9  2016-10-01        PC  Percentage               0     Units
# 10 2016-11-01        PC  Percentage               0     Units
# 11 2016-12-01        PC  Percentage               0     Units
# 12 2017-01-01        PC  Percentage               0     Units
# 13 2017-02-01        PC  Percentage               0     Units
# 14 2017-03-01        PC  Percentage               0     Units
# 15 2017-04-01        PC  Percentage               0     Units
# 16 2017-05-01        PC  Percentage               0     Units
# 17 2017-06-01        PC  Percentage               0     Units
# 18 2017-07-01        PC  Percentage               0     Units
# 19 2017-08-01        PC  Percentage               0     Units
#
#     Reference Period Code  Reference Period  Employment Rate  Flag Codes  \
# 0                     NaN               NaN         63.96228         NaN
# 1                     NaN               NaN         63.97734         NaN
# 2                     NaN               NaN         64.02754         NaN
# 3                     NaN               NaN         63.86652         NaN
# 4                     NaN               NaN         64.00909         NaN
# 5                     NaN               NaN         63.73130         NaN
# 6                     NaN               NaN         63.95990         NaN
# 7                     NaN               NaN         64.05479         NaN
# 8                     NaN               NaN         64.16472         NaN
# 9                     NaN               NaN         64.21517         NaN
# 10                    NaN               NaN         64.26853         NaN
# 11                    NaN               NaN         64.29591         NaN
# 12                    NaN               NaN         64.31509         NaN
# 13                    NaN               NaN         64.58833         NaN
# 14                    NaN               NaN         65.05240         NaN
# 15                    NaN               NaN         64.89852         NaN
# 16                    NaN               NaN         64.74586         NaN
# 17                    NaN               NaN         64.90868         NaN
# 18                    NaN               NaN         65.08848         NaN
# 19                    NaN               NaN         65.07627         NaN
#
#     Flags
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN

# %%
combined_data=pd.merge(employment,stock_monthly,on='Year Month', how='inner')
combined_data.head()
# Out:
#   LOCATION        Country   SUBJECT                                   Subject  \
# 0      USA  United States  LREM64FE      Employment rate, Aged 15-64, Females
# 1      USA  United States  LREM64MA        Employment rate, Aged 15-64, Males
# 2      USA  United States  LREM64TT  Employment rate, Aged 15-64, All persons
# 3      USA  United States  LREM64FE      Employment rate, Aged 15-64, Females
# 4      USA  United States  LREM64MA        Employment rate, Aged 15-64, Males
#
#   MEASURE                               Measure FREQUENCY Frequency     TIME  \
# 0    STSA  Level, rate or quantity series, s.a.         M   Monthly  2017-01
# 1    STSA  Level, rate or quantity series, s.a.         M   Monthly  2017-01
# 2    STSA  Level, rate or quantity series, s.a.         M   Monthly  2017-01
# 3    STSA  Level, rate or quantity series, s.a.         M   Monthly  2017-02
# 4    STSA  Level, rate or quantity series, s.a.         M   Monthly  2017-02
#
#   Year Month Unit Code        Unit  PowerCode Code PowerCode  \
# 0 2017-01-01        PC  Percentage               0     Units
# 1 2017-01-01        PC  Percentage               0     Units
# 2 2017-01-01        PC  Percentage               0     Units
# 3 2017-02-01        PC  Percentage               0     Units
# 4 2017-02-01        PC  Percentage               0     Units
#
#    Reference Period Code  Reference Period  Employment Rate  Flag Codes  \
# 0                    NaN               NaN         64.31509         NaN
# 1                    NaN               NaN         75.17329         NaN
# 2                    NaN               NaN         69.65945         NaN
# 3                    NaN               NaN         64.58833         NaN
# 4                    NaN               NaN         75.10329         NaN
#
#    Flags       Close
# 0    NaN  126.817499
# 1    NaN  126.817499
# 2    NaN  126.817499
# 3    NaN  133.830525
# 4    NaN  133.830525

# %%
employment_and_interest=combined_data[['Year Month','Employment Rate','Close']]
employment_and_interest.head(27)
# Out:
#    Year Month  Employment Rate       Close
# 0  2017-01-01         64.31509  126.817499
# 1  2017-01-01         75.17329  126.817499
# 2  2017-01-01         69.65945  126.817499
# 3  2017-02-01         64.58833  133.830525
# 4  2017-02-01         75.10329  133.830525
# 5  2017-02-01         69.76285  133.830525
# 6  2017-03-01         65.05240  139.408261
# 7  2017-03-01         75.17853  139.408261
# 8  2017-03-01         70.03338  139.408261
# 9  2017-04-01         64.89852  142.965263
# 10 2017-04-01         75.47026  142.965263
# 11 2017-04-01         70.09789  142.965263
# 12 2017-05-01         64.74586  150.234093
# 13 2017-05-01         75.37952  150.234093
# 14 2017-05-01         69.97665  150.234093
# 15 2017-06-01         64.90868  152.079545
# 16 2017-06-01         75.45502  152.079545
# 17 2017-06-01         70.09774  152.079545
# 18 2017-07-01         65.08848  160.532499
# 19 2017-07-01         75.38754  160.532499
# 20 2017-07-01         70.15578  160.532499
# 21 2017-08-01         65.07627  169.160000
# 22 2017-08-01         75.42780  169.160000
# 23 2017-08-01         70.17014  169.160000
# 24 2017-09-01         65.33665  170.591000
# 25 2017-09-01         75.78501  170.591000
# 26 2017-09-01         70.47729  170.591000

# %%
plt.figure(figsize=(10,8))
plt.scatter(employment_and_interest["Employment Rate"], employment_and_interest["Close"], color='b', alpha=0.5)
plt.grid()
plt.xlabel('Employment Rate')
plt.ylabel('Facebook Avg Monthly Close Price')
plt.title('Facebook Stock Price vs Employment Rate')
plt.show()

# %%
trump="trump.csv"
trump_approval = pd.read_csv(trump)
trump_approval.head(20)
# Out:
#          survey_organization party_affiliation  start_date    end_date  \
# 0                     Gallup              None  2017-01-20  2017-01-22
# 1              Ipsos/Reuters              None  2017-01-20  2017-01-24
# 2              Ipsos/Reuters              None  2017-01-20  2017-01-24
# 3              Ipsos/Reuters              None  2017-01-20  2017-01-24
# 4              Ipsos/Reuters              None  2017-01-20  2017-01-24
# 5   Politico/Morning Consult              None  2017-01-20  2017-01-22
# 6   Politico/Morning Consult              None  2017-01-20  2017-01-22
# 7   Politico/Morning Consult              None  2017-01-20  2017-01-22
# 8   Politico/Morning Consult              None  2017-01-20  2017-01-22
# 9                 Quinnipiac              None  2017-01-20  2017-01-25
# 10                Quinnipiac              None  2017-01-20  2017-01-25
# 11                Quinnipiac              None  2017-01-20  2017-01-25
# 12                Quinnipiac              None  2017-01-20  2017-01-25
# 13                    Gallup              None  2017-01-21  2017-01-23
# 14                    Gallup              None  2017-01-22  2017-01-24
# 15                 Rasmussen              None  2017-01-22  2017-01-24
# 16                    Gallup              None  2017-01-23  2017-01-25
# 17                   PPP (D)          Democrat  2017-01-23  2017-01-24
# 18                   PPP (D)          Democrat  2017-01-23  2017-01-24
# 19                   PPP (D)          Democrat  2017-01-23  2017-01-24
#
#                survey_method  \
# 0                 Live Phone
# 1                   Internet
# 2                   Internet
# 3                   Internet
# 4                   Internet
# 5                   Internet
# 6                   Internet
# 7                   Internet
# 8                   Internet
# 9                 Live Phone
# 10                Live Phone
# 11                Live Phone
# 12                Live Phone
# 13                Live Phone
# 14                Live Phone
# 15  Automated Phone/Internet
# 16                Live Phone
# 17  Automated Phone/Internet
# 18  Automated Phone/Internet
# 19  Automated Phone/Internet
#
#                                       survey_question  \
# 0                                                 NaN
# 1   Overall, do you approve or disapprove about th...
# 2   Overall, do you approve or disapprove about th...
# 3   Overall, do you approve or disapprove about th...
# 4   Overall, do you approve or disapprove about th...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   Do you approve or disapprove of the way Donald...
# 10  Do you approve or disapprove of the way Donald...
# 11  Do you approve or disapprove of the way Donald...
# 12  Do you approve or disapprove of the way Donald...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  Do you approve or disapprove of President Dona...
# 18  Do you approve or disapprove of President Dona...
# 19  Do you approve or disapprove of President Dona...
#
#                    survey_population  survey_sample  approve_percent  \
# 0                             Adults         1500.0               45
# 1                             Adults         1633.0               43
# 2                 Adults (Democrats)          680.0               15
# 3               Adults (Republicans)          557.0               85
# 4              Adults (Independents)          228.0               38
# 5                  Registered Voters         1992.0               46
# 6      Registered Voters (Democrats)          744.0               18
# 7    Registered Voters (Republicans)          642.0               83
# 8   Registered Voters (Independents)          606.0               41
# 9                  Registered Voters         1190.0               36
# 10     Registered Voters (Democrats)            NaN                4
# 11   Registered Voters (Republicans)            NaN               81
# 12  Registered Voters (Independents)            NaN               35
# 13                            Adults         1500.0               45
# 14                            Adults         1500.0               46
# 15                     Likely Voters         1500.0               57
# 16                            Adults         1500.0               46
# 17                     Likely Voters         1043.0               44
# 18         Likely Voters (Democrats)            NaN               14
# 19       Likely Voters (Republicans)            NaN               84
#
#     disapprove_percent  undecided_percent  margin_of_error
# 0                   45                NaN              3.0
# 1                   45               13.0              2.8
# 2                   75               10.0              4.3
# 3                   11                4.0              4.7
# 4                   39               23.0              7.4
# 5                   37               17.0              2.0
# 6                   67               15.0              NaN
# 7                    8                9.0              NaN
# 8                   31               28.0              NaN
# 9                   44               19.0              2.8
# 10                  77               19.0              NaN
# 11                   3               15.0              NaN
# 12                  45               20.0              NaN
# 13                  46                NaN              3.0
# 14                  45                NaN              3.0
# 15                  43                NaN              2.5
# 16                  45                NaN              3.0
# 17                  44               12.0              3.0
# 18                  77                9.0              NaN
# 19                   9                7.0              NaN

# %%
trump_gallup=trump_approval.loc[trump_approval['survey_organization']=='Gallup']
trump_ratings=trump_gallup[["end_date","approve_percent"]]
trump_disapproval=trump_ratings.rename(columns={"end_date":"Date","approve_percent":"Approval Percentage" })
trump_disapproval.head()
# Out:
#           Date  Approval Percentage
# 0   2017-01-22                   45
# 13  2017-01-23                   45
# 14  2017-01-24                   46
# 16  2017-01-25                   46
# 26  2017-01-26                   45

# %%
combined=pd.merge(trump_disapproval,stock_price,on='Date', how='inner')
combined.head(40)
# Out:
#           Date  Approval Percentage       Close
# 0   2017-01-23                   45  128.929993
# 1   2017-01-24                   46  129.369995
# 2   2017-01-25                   46  131.479996
# 3   2017-01-26                   45  132.779999
# 4   2017-01-27                   42  132.179993
# 5   2017-01-30                   43  130.979996
# 6   2017-01-31                   43  130.320007
# 7   2017-02-01                   43  133.229996
# 8   2017-02-02                   43  130.839996
# 9   2017-02-03                   44  130.979996
# 10  2017-02-06                   42  132.059998
# 11  2017-02-07                   43  131.839996
# 12  2017-02-08                   43  134.199997
# 13  2017-02-09                   42  134.139999
# 14  2017-02-10                   41  134.190002
# 15  2017-02-13                   40  134.050003
# 16  2017-02-14                   40  133.850006
# 17  2017-02-15                   40  133.440002
# 18  2017-02-16                   38  133.839996
# 19  2017-02-17                   40  133.529999
# 20  2017-02-21                   42  133.720001
# 21  2017-02-22                   43  136.119995
# 22  2017-02-23                   43  135.360001
# 23  2017-02-24                   41  135.440002

# %%
plt.figure(figsize=(10,8))
plt.scatter(combined["Approval Percentage"], combined["Close"], color='b', alpha=0.5)
plt.grid()
plt.xlabel('Trump Approval Rate')
plt.ylabel('Facebook Avg Monthly Close Price')
plt.title('Facebook Stock Price vs Trump Approval Rate')
plt.show()
